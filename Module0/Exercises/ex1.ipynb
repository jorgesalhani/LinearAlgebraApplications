# %%
import matplotlib.pyplot as plt
import numpy as np
import gc

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# ### (a)

# %%
fig, ax = plt.subplots()
ax.plot(2, -1, 'bo', label='A')
ax.plot(-1,1, 'go', label='B')

t = np.linspace(-5, 10, 100)
x = -1 - 3 * t
y = 1 + 2 * t

ax.set_xlim(-3, 3)
ax.set_ylim(-3, 5)
ax.plot(x,y, 'k-', label=r'Linha $r$')
ax.legend(frameon = True, framealpha=1)
plt.show()

# %% [markdown]
# ### (b)

# %%
fig, ax = plt.subplots()
ax.plot(-5,5, 'go', label='A')

t = np.linspace(-5, 10, 100)
l = - t
x = -5 - 2 * t
y = 5 + 2 * t

ax.plot(t, l, 'b-', label=r'Linha $l$')
ax.plot(x, y, 'k-', label=r'Linha r')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ### (c)

# %%
fig, ax = plt.subplots()
ax.plot(-4, -9, 'go', label='A')

t = np.linspace(-5, 10, 100)
x_l = 2 + 2 * t
y_l = 3 - t

x = -4 + 2 * t
y = -9 - t

ax.legend(frameon=True)
ax.plot(x_l, y_l, 'b-', label=r'Linha $l$')
ax.plot(x, y, 'k-', label=r'Linha $r$')
plt.show()

# %% [markdown]
# ### (d)

# %%
fig, ax = plt.subplots()
ax.plot(2,3, 'go', label='A')

t = np.linspace(-5, 10, 100)

x = 2 + t * 0
y = 3 + 3 * t

ax.plot(x, y, 'k-', label=r'Linha $r$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ### (e)

# %%
fig, ax = plt.subplots()
ax.plot(4,2, 'go', label='A')

t = np.linspace(-5,10,100)

x_l = t
y_l = 2 + t

x = 4 - t
y = 2 + t

ax.plot(x_l, y_l, 'b-', label=r'Linha $l$')
ax.plot(x, y, 'k-', label=r'Linha $r$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Retas $r$ e $l$ paralelas

# %%
fig, ax = plt.subplots()
ax.plot(1,2, 'go', label='A')
ax.plot(3,-2, 'co', label='B')
ax.plot(-3,4, 'ro', label='C')
ax.plot(0,-2, 'mo', label='D')

t = np.linspace(-5,10, 100)
x_r = 1 + 2 * t
y_r = 2 - 4 * t

x_l = -3 + 3 * t
y_l = 4 - 6 * t


ax.plot(x_r, y_r, 'k-', label=r'Linha $r$')
ax.plot(x_l, y_l, 'b-', label=r'Linha $l$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# Retas $r$ e $l$ perpendiculares

# %%
fig, ax = plt.subplots()
ax.plot(1,2, 'go', label='A')
ax.plot(3,-2, 'co', label='B')
ax.plot(-3,4, 'ro', label='C')
ax.plot(0,11/2, 'mo', label='D')

t = np.linspace(-5,10, 100)
x_r = 1 + 2 * t
y_r = 2 - 4 * t

x_l = -3 + 3 * t
y_l = 4 + (3/2 * t)

ax.set_xlim(-10,8)
ax.set_ylim(-10,8)
ax.plot(x_r, y_r, 'k-', label=r'Linha $r$')
ax.plot(x_l, y_l, 'b-', label=r'Linha $l$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ## Exercício 3

# %% [markdown]
# ### (a)

# %%
fig, ax = plt.subplots()

t = np.linspace(-5,10, 100)
y_r = 2 * t - 2
y_l = 3 - 3 * t

ax.plot(1,0,'go', label='A')

ax.plot(t, y_r, 'k-', label=r'Linha $r$')
ax.plot(t, y_l, 'b-', label=r'Linha $l$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ### (b)

# %%
fig, ax = plt.subplots()

t = np.linspace(-5,10, 100)
y_r = (5 * t - 3) / 7
y_l = (10 * t - 5)/ 14

ax.set_xlim(0,2)
ax.set_ylim(-1,1)
ax.plot(t, y_r, 'k-', label=r'Linha $r$')
ax.plot(t, y_l, 'b-', label=r'Linha $l$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ### (c)

# %%
fig, ax = plt.subplots()

t = np.linspace(-5,10, 100)
y_r = (4 - t) / 2
y_l = (10 - 3 * t) / 4

ax.plot(2,1,'go', label='A')

ax.plot(t, y_r, 'k-', label=r'Linha $r$')
ax.plot(t, y_l, 'b-', label=r'Linha $l$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ## Exercício 4

# %%
fig, ax = plt.subplots()

t = np.linspace(-5,10, 100)
y_r = 2 * t + 1
y_l = 3 * t - 2
y_s = 1 - t

ax.plot(3,7,'go', label='A')
ax.plot(0,1,'co', label='B')
ax.plot(3/4,1/4,'mo', label='C')

ax.set_xlim(-2, 4)
ax.set_ylim(-2, 10)

ax.plot(t, y_r, 'k-', label=r'Linha $r$')
ax.plot(t, y_l, 'b-', label=r'Linha $l$')
ax.plot(t, y_s, 'r-', label=r'Linha $s$')
ax.legend(frameon=True)
plt.show()

# %% [markdown]
# ## Exercício 5

# %% [markdown]
# ### (a)
